# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np
import sys 
sys.path.append('..')
from scripts import project_fuctions as pf

# %%
DF_main = pf.load_and_process()

housePrices_DF = pf.loadMLSRegionalHPIData()



allData = pf.loadAll()

# %%
DF_main.head()
# Out:
#                                                  1960  1961  1962  1963  1964  \
# All-items                                        <NA>  <NA>  <NA>  <NA>  <NA>
# Food                                             <NA>  <NA>  <NA>  <NA>  <NA>
# Shelter                                          <NA>  <NA>  <NA>  <NA>  <NA>
# Household operations, furnishings and equipment  <NA>  <NA>  <NA>  <NA>  <NA>
# Clothing and footwear                            <NA>  <NA>  <NA>  <NA>  <NA>
#
#                                                  1965  1966  1967  1968  1969  \
# All-items                                        <NA>  <NA>  <NA>  <NA>  <NA>
# Food                                             <NA>  <NA>  <NA>  <NA>  <NA>
# Shelter                                          <NA>  <NA>  <NA>  <NA>  <NA>
# Household operations, furnishings and equipment  <NA>  <NA>  <NA>  <NA>  <NA>
# Clothing and footwear                            <NA>  <NA>  <NA>  <NA>  <NA>
#
# ...

# %%
ax = sns.relplot(y='Unemployment, total (% of total labor force) (modeled ILO estimate)', x='Alcoholic beverages, tobacco products and recreational cannabis', 
                 data=dfyearsBack.transpose(),hue=dfyearsBack.columns,)
#This shows a direct relationship between unemployment numbers versus total spending on Alcohol, tobacco, and recreational marijuana use. As we can see from the relative plot
#when  starting at 1995, unemployment is at 9.5% in Canada and as we increase yearly we can see an increase in the spending of Alcohol, tobacco, and marijuana as unemployment 
#rates drop and people have a greater surplus of income to spend. Approximately every 6-7 years the Unemployment rate increase and we again see a decrese in spending on the x axis. 
#What is interesting is that in 2020, during covid-19, unemployment has increased so it will be interesting to see what the grahp does in the next 6-7 years, if I had to make
#an educateedd guess I believe we will see a trend just as before.

# %%
dfyearsBack = pf.limitYears(DF_main, 27)
dfyearsBack.head()
# Out:
#                                                  1995  1996  1997  1998  \
# All-items                                        87.6  88.9  90.4  91.3
# Food                                             86.9  88.0  89.4  90.9
# Shelter                                          90.4  90.6  90.8  91.1
# Household operations, furnishings and equipment  90.6  92.5  93.7  95.1
# Clothing and footwear                            96.7  96.4  97.7  98.8
#
#                                                   1999   2000   2001   2002  \
# All-items                                         92.9   95.4   97.8  100.0
# Food                                              92.0   93.3   97.4  100.0
# Shelter                                           92.3   95.6   99.1  100.0
# Household operations, furnishings and equipment   95.8   96.7   98.6  100.0
# Clothing and footwear                            100.1  100.3  100.7  100.0
#
# ...

# %%
housePrices_DF.head()
# Out:
#             Vancouver One Storey Home  Vancouver Two Storey Home  \
# Date
# 2005-01-01                     435200                     616100
# 2005-02-01                     435300                     615700
# 2005-03-01                     435300                     614300
# 2005-04-01                     436300                     614500
# 2005-05-01                     437800                     616600
#
#             Vancouver Townhouse  Vancouver Apartment  Kelowna One Storey Home  \
# Date
# 2005-01-01               314600               252600                   268300
# 2005-02-01               315700               253600                   267900
# 2005-03-01               316700               254900                   268900
# 2005-04-01               318000               255500                   268200
# 2005-05-01               319800               258100                   269300
#
#             Kelowna Two Storey Home  Kelowna Townhouse  Kelowna Apartment  \
# Date
# ...

# %%
from ipywidgets import interactive
def size_widget(height=1.8, aspect=1.18):#these are the defaults for height and aspect
    sns.pairplot(housePrices_DF, corner=True, height=height, aspect=aspect)
#This compares the housing prices in Canada ans well as a couple of the major cities such as Vancouver and Kelowna from the years 2005-2021 for various homes such as Townhouese, Apartments, 
#One and Two Storey Homes. The pairplot easily allows us to compare one vs the other, and for the mostpart have an increasing slope some more than others.  
#I followed a youtube tutorial to make a slider for height and it creates the new plot in a new window:   https://www.youtube.com/watch?v=uCgvlfIo9fg
#Kimberly Fessel Seaborn pairplot | How to make a pairplot in Python and the Seaborn pairplot interpretation

# %%
interactive(size_widget, height=(1, 3.5, 0.2), aspect=(0.5, 2, 0.05))
# Out:
# interactive(children=(FloatSlider(value=1.8, description='height', max=3.5, min=1.0, step=0.2), FloatSlider(va…
