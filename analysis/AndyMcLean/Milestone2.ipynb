# %% [markdown]
# # Data 301 Project Milestone 2 for Group11

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np
import sys
sys.path.append('..')
from project_scripts import project_fuctions as pf

# %%
DF_main = pf.load_and_process()

housePrices_DF = pf.loadMLSRegionalHPIData()



allData = pf.loadAll()

# %%
DF_main.head()
# Out:
#                                                  1960  1961  1962  1963  1964  \
# All-items                                        <NA>  <NA>  <NA>  <NA>  <NA>
# Food                                             <NA>  <NA>  <NA>  <NA>  <NA>
# Shelter                                          <NA>  <NA>  <NA>  <NA>  <NA>
# Household operations, furnishings and equipment  <NA>  <NA>  <NA>  <NA>  <NA>
# Clothing and footwear                            <NA>  <NA>  <NA>  <NA>  <NA>
#
#                                                  1965  1966  1967  1968  1969  \
# All-items                                        <NA>  <NA>  <NA>  <NA>  <NA>
# Food                                             <NA>  <NA>  <NA>  <NA>  <NA>
# Shelter                                          <NA>  <NA>  <NA>  <NA>  <NA>
# Household operations, furnishings and equipment  <NA>  <NA>  <NA>  <NA>  <NA>
# Clothing and footwear                            <NA>  <NA>  <NA>  <NA>  <NA>
#
# ...

# %%
ax = sns.relplot(y='Unemployment, total (% of total labor force) (modeled ILO estimate)', x='Alcoholic beverages, tobacco products and recreational cannabis', 
                 data=dfyearsBack.transpose(),hue=dfyearsBack.columns,)
plt.title("Graph of Unemployment vs cost of Alcohol, Tobacco and Marijuana", size =10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_788/3809272914.py in <module>
#       1 ax = sns.relplot(y='Unemployment, total (% of total labor force) (modeled ILO estimate)', x='Alcoholic beverages, tobacco products and recreational cannabis',
# ----> 2                  data=dfyearsBack.transpose(),hue=dfyearsBack.columns,)
#       3 plt.title("Graph of Unemployment vs cost of Alcohol, Tobacco and Marijuana", size =10)
#
# NameError: name 'dfyearsBack' is not defined

# %% [markdown]
# This shows a direct relationship between unemployment numbers versus total spending on Alcohol, tobacco, and recreational marijuana use. As we can see from the relative plot when  starting at 1995, unemployment is at 9.5% in Canada and as we increase yearly we can see an increase in the spending of Alcohol, tobacco, and marijuana as unemployment #rates drop and people have a greater surplus of income to spend. Approximately every 6-7 years the Unemployment rate increase and we again see a decrese in spending on the x axis. What is interesting is that in 2020, during covid-19, unemployment has increased so it will be interesting to see what the grahp does in the next 6-7 years, if I had to make an educateedd guess I believe we will see a trend just as before.

# %%
dfyearsBack = pf.limitYears(DF_main, 35)
dfyearsBack.head()
# Out:
#                                                  1987  1988  1989  1990  1991  \
# All-items                                        68.5  71.2  74.8  78.4  82.8
# Food                                             71.8  73.7  76.5  79.6  83.4
# Shelter                                          70.5  73.8  78.1  82.5  86.3
# Household operations, furnishings and equipment  76.7  79.6  82.5  84.2  87.4
# Clothing and footwear                            76.5  80.5  83.7  86.1  94.3
#
#                                                  1992  1993  1994  1995  1996  \
# All-items                                        84.0  85.6  85.7  87.6  88.9
# Food                                             83.1  84.5  84.9  86.9  88.0
# Shelter                                          87.9  89.1  89.4  90.4  90.6
# Household operations, furnishings and equipment  87.9  88.7  88.9  90.6  92.5
# Clothing and footwear                            95.1  96.0  96.8  96.7  96.4
#
# ...

# %%
housePrices_DF.head()
# Out:
#             Vancouver One Storey Home  Vancouver Two Storey Home  \
# Date
# 2005-01-01                     435200                     616100
# 2005-02-01                     435300                     615700
# 2005-03-01                     435300                     614300
# 2005-04-01                     436300                     614500
# 2005-05-01                     437800                     616600
#
#             Vancouver Townhouse  Vancouver Apartment  Kelowna One Storey Home  \
# Date
# 2005-01-01               314600               252600                   268300
# 2005-02-01               315700               253600                   267900
# 2005-03-01               316700               254900                   268900
# 2005-04-01               318000               255500                   268200
# 2005-05-01               319800               258100                   269300
#
#             Kelowna Two Storey Home  Kelowna Townhouse  Kelowna Apartment  \
# Date
# ...

# %%
from ipywidgets import interactive
def size_widget(height=1.8, aspect=1.18):#these are the defaults for height and aspect
    sns.pairplot(housePrices_DF, corner=True, height=height, aspect=aspect)

#I followed a youtube tutorial to make a slider for height and it creates the new plot in a new window:   https://www.youtube.com/watch?v=uCgvlfIo9fg
#Kimberly Fessel Seaborn pairplot | How to make a pairplot in Python and the Seaborn pairplot interpretation

# %%
interactive(size_widget, height=(1, 3.5, 0.2), aspect=(0.5, 2, 0.05))
# Out:
# interactive(children=(FloatSlider(value=1.8, description='height', max=3.5, min=1.0, step=0.2), FloatSlider(va…

# %% [markdown]
# This compares the housing prices in Canada ans well as a couple of the major cities such as Vancouver and Kelowna from the years 2005-20210 for various homes such as Townhouses, Apartments, One and Two Storey Homes. The pairplot easily allows us to compare one vs the other, and if we look at Kelowna one storey homes and Vancouver two storey homees we see anon  lineasr graph approx. at around the year 2008, where there weas a housing market crash.

# %%
pf.limitYears(DF_main,25).transpose()
#housePrices_DF.head()
# Out:
#       All-items   Food  Shelter  \
# 1997       90.4   89.4     90.8
# 1998       91.3   90.9     91.1
# 1999       92.9   92.0     92.3
# 2000       95.4   93.3     95.6
# 2001       97.8   97.4     99.1
# 2002      100.0  100.0    100.0
# 2003      102.8  101.7    103.2
# 2004      104.7  103.8    105.8
# 2005      107.0  106.4    109.2
# 2006      109.1  108.9    113.1
# 2007      111.5  111.8    116.9
# 2008      114.1  115.7    122.0
# 2009      114.4  121.4    121.6
# 2010      116.5  123.1    123.3
# 2011      119.9  127.7    125.6
# 2012      121.7  130.8    127.1
# 2013      122.8  132.4    128.7
# 2014      125.2  135.5    132.2
# 2015      126.6  140.5    133.7
# 2016      128.4  142.6    135.8
# 2017      130.4  142.7    138.1
# 2018      133.4  145.3    140.9
# 2019      136.0  150.2    144.5
# 2020      137.0  153.7    147.0
#
#       Household operations, furnishings and equipment  Clothing and footwear  \
# ...

# %%
dfyearsBack2 = pf.limitYears(DF_main, 20)
dfyearsBack2.head()
# Out:
#                                                   2002   2003   2004   2005  \
# All-items                                        100.0  102.8  104.7  107.0
# Food                                             100.0  101.7  103.8  106.4
# Shelter                                          100.0  103.2  105.8  109.2
# Household operations, furnishings and equipment  100.0  100.7  101.2  101.7
# Clothing and footwear                            100.0   98.2   98.0   97.6
#
#                                                   2006   2007   2008   2009  \
# All-items                                        109.1  111.5  114.1  114.4
# Food                                             108.9  111.8  115.7  121.4
# Shelter                                          113.1  116.9  122.0  121.6
# Household operations, furnishings and equipment  102.2  103.2  104.6  107.3
# Clothing and footwear                             95.8   95.7   93.8   93.4
#
# ...

# %%
sns.barplot(data=dfyearsBack2.transpose(), x='Urban population growth (annual %)', y='BC New Housing Price Index').set(title="Urban population growth vs British Columbia new housing Price Index")


sns.set(rc={"figure.figsize":(28, 5)})
my_cmap = plt.cm.get_cmap('YlOrRd')

#This is a plot between Urban population growth on the x axis and British Columbia new housing Price Index from 2001 to 2020,

# %%
pf.barPlotOverTime(DF_main, "Urban population", 30, 10,10, "yellow")

# %% [markdown]
# There werw housing market crashes in 1993, and 2008 and from this data correlated we do not see any corresponding drop in Urban Pop. as it increases at a steady linear rate.

# %%
pf.barPlotOverTime(DF_main, "Gasoline", 30, 15,10, "orange")

# %% [markdown]
# Recalling there were housing market crashes in 1993 and 2008, we do not see a correlation betwee Gasoline prices and the housing market crash for 1993, but do see a downward slide in 2009, so we a re unable to determine any correlation, or there may not be one between the two.

# %%
data1=dfyearsBack.transpose()
sns.jointplot(x = data1['Bank of Canada Overnight Rate'], y = data1['Prime Rate'], kind = 'hist')

# %% [markdown]
# # This Joint plot views the relationship between Prime Rate and Bank of Canada Overnight Rate throughout the years, showing that they are closely linked.

# %%
sns.heatmap(data1.corr(), annot = True, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # This is a correlation plot showing all the values within our dataset compariong one to another, with a maximum value of 1 and a minimum correlational value of 0. Purple carries with it a minimum correlational value while yellow is the highest
