# %%
import pandas as pd

# %%
HousingData1 = pd.read_excel("../../data/raw/Seasonally Adjusted.xlsx")
HousingData2 = pd.read_csv("../../data/processed/1810000501-noSymbol.csv")
HousingData1.head()
# Out:
#         Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0 2005-01-01             100.0                 100.0              100.0
# 1 2005-02-01             100.2                 100.2              100.2
# 2 2005-03-01             100.5                 100.6              100.8
# 3 2005-04-01             100.7                 100.8              101.0
# 4 2005-05-01             100.9                 101.1              101.4
#
#    Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# 0              100.0             100.0             100.0
# 1              100.3             100.4             100.5
# 2              100.7             100.7             100.6
# 3              101.0             101.0             100.8
# 4              101.1             101.1             101.1
#
#    Composite_Benchmark_SA  Single_Family_Benchmark_SA  \
# 0                  246200                      264500
# 1                  246700                      265000
# ...

# %%
HousingData2.head()
# Out:
#                      Products and product groups 4  1985  1986  1987  1988  \
# 0                                        All-items  63.0  65.6  68.5  71.2
# 1                                           Food 5  65.5  68.8  71.8  73.7
# 2                                        Shelter 6  65.6  67.5  70.5  73.8
# 3  Household operations, furnishings and equipment  72.3  74.5  76.7  79.6
# 4                            Clothing and footwear  71.5  73.4  76.5  80.5
#
#    1989  1990  1991  1992  1993  ...   2011   2012   2013   2014   2015  \
# 0  74.8  78.4  82.8  84.0  85.6  ...  119.9  121.7  122.8  125.2  126.6
# 1  76.5  79.6  83.4  83.1  84.5  ...  127.7  130.8  132.4  135.5  140.5
# 2  78.1  82.5  86.3  87.9  89.1  ...  125.6  127.1  128.7  132.2  133.7
# 3  82.5  84.2  87.4  87.9  88.7  ...  110.9  113.0  114.4  116.6  119.7
# 4  83.7  86.1  94.3  95.1  96.0  ...   91.9   92.0   92.1   93.2   94.6
#
#     2016   2017   2018   2019   2020
# 0  128.4  130.4  133.4  136.0  137.0
# ...

# %%
HousingData1.drop(columns=['Single_Family_HPI_SA','One_Storey_HPI_SA','One_Storey_HPI_SA','One_Storey_Benchmark_SA','Single_Family_Benchmark_SA'])
# Out:
#           Date  Composite_HPI_SA  Two_Storey_HPI_SA  Townhouse_HPI_SA  \
# 0   2005-01-01             100.0              100.0             100.0
# 1   2005-02-01             100.2              100.3             100.4
# 2   2005-03-01             100.5              100.7             100.7
# 3   2005-04-01             100.7              101.0             101.0
# 4   2005-05-01             100.9              101.1             101.1
# ..         ...               ...                ...               ...
# 192 2021-01-01             267.2              278.9             265.6
# 193 2021-02-01             274.9              288.8             272.7
# 194 2021-03-01             282.6              297.9             280.1
# 195 2021-04-01             288.3              302.1             287.5
# 196 2021-05-01             291.2              305.1             292.4
#
#      Apartment_HPI_SA  Composite_Benchmark_SA  Two_Storey_Benchmark_SA  \
# ...
